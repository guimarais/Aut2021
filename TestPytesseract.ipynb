# %%
import pandas as pd
from IPython.display import display # to display images
import pytesseract
from PIL import Image

# %% [markdown]
# Temos a imagem Testpic1.png na diretoria Files para experimentar.

# %%
pil_im = Image.open('./Files/Testpic1.png', 'r')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=738x957 at 0x7F988C8142B0>

# %%
#Reconhecimento de caracteres
print(pytesseract.image_to_string(Image.open('./Files/Testpic1.png')))
# Out:
# Listas:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nome Nevolt
# [Tiago de Matos Gomes
# Guilherme PTOOO1
# Sandra Maria Rosa Marques PT0139
# lAbel Fernando Barros
# Rodrigues P0201
# JAna Rebeca Steingraber
# Gradissimo PTO010
# [Aldénio José Pires Pestana Independente
# Silke Jellen Geb. Wolff P0168
# Nandan Niranjan Bhoopalam P0035
# Melanie Constanca Rodrigues
# dos Santos PTO185
# Filipe Neto Rodeia Macedo P0170
# Leonor Botelho Pereira Neves
# Baptista PT0041
# Rui Hermes Martins Fernandes
# INunes PTOOS9
# Maria Isabel Milheirico Fontes
# Cabral Monjardino P0020
# JAFonso da Costae Silva
# Carvalho Alves P0013,
# Helena Isabel Goncalves Luis
# Estima Martins PTO070
# [Joao Tomas Carilho Roque PT0140
# Maria Francisca Burnay
# Gonzalez Rey PTO121
# José Manuel Rodrigues de
# Almeida PTOOOS
# [Ana Patricia Simdes Goncalves
# lde Carvalho P0003,
# lAnténio Mateus Simao da
# Conceicao Ferreira de Carvalho P0002
# ...

# %%
pil_im = Image.open('./Files/Testpic2.png', 'r')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=624x952 at 0x7F9894865F10>

# %%
#Reconhecimento de caracteres
print(pytesseract.image_to_string(Image.open('./Files/Testpic2.png')))
# Out:
# Fabio André Dias Almeida PTO149
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Olga Dyeda Goncalves Independente
# [Rui Pedro de Melo Dias PT0015
# Larisa Tovmasyan Independente
# Marcos Rosa La de Melo
#
# Antunes PToo12
# Carla Lickfold de Matos Gomes Independente
# [Alexandre Barros Paulo Pro177
# Carla Marina Pita dos Santos Prova
# Laurens William Alexander
#
# Asamoah PToo0s
# Maria Natalia Serpa de Matos
#
# Gomes Guilherme Independente
# Carl Macken Dawson PTO147
# Helena Isabel Goncalves Luis
#
# Estima Martins T0070
# ‘Afonso da Costae Silva
#
# ‘Carvalho Alves PT0013
# ‘Leonor Botelho Pereira Neves
#
# Baptista P0041
# 4080 Carlos Bessa da Cruz
#
# Pereira PTO194
# Melanie Constanca Rodrigues
#
# dos Santos PTo1gs
# Miguel Cunha Duarte PTOO21
# Silke Jellen Geb. Wolff PT0O168
# Paulo Alexandre Marinho
#
# Figueiredo PT0014
# ‘Ana Rebeca Steingraber
#
# \Gradissimo T0010
# Ruben Miguel Silva Vitorino PTO148
# ...
